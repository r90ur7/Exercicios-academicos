# %%
n = 0
Soma = 0
soma = Soma
while (n <= 100 ):
 n = n + 1
 Soma = 0 + soma
 soma = Soma
 print("a soma de ",n,"+",soma,"é",n + soma)
 print(Soma)

 


    
 
#
#
# Out:
# a soma de  0 + 0 é 0
# a soma de  1 + 1 é 1
# a soma de  3 + 2 é 3
# a soma de  6 + 3 é 6
# a soma de  10 + 4 é 10
# a soma de  15 + 5 é 15
# a soma de  21 + 6 é 21
# a soma de  28 + 7 é 28
# a soma de  36 + 8 é 36
# a soma de  45 + 9 é 45
# a soma de  55 + 10 é 55
# a soma de  66 + 11 é 66
# a soma de  78 + 12 é 78
# a soma de  91 + 13 é 91
# a soma de  105 + 14 é 105
# a soma de  120 + 15 é 120
# a soma de  136 + 16 é 136
# a soma de  153 + 17 é 153
# a soma de  171 + 18 é 171
# a soma de  190 + 19 é 190
# a soma de  210 + 20 é 210
# a soma de  231 + 21 é 231
# a soma de  253 + 22 é 253
# a soma de  276 + 23 é 276
# a soma de  300 + 24 é 300
# a soma de  325 + 25 é 325
# a soma de  351 + 26 é 351
# a soma de  378 + 27 é 378
# a soma de  406 + 28 é 406
# a soma de  435 + 29 é 435
# a soma de  465 + 30 é 465
# a soma de  496 + 31 é 496
# a soma de  528 + 32 é 528
# a soma de  561 + 33 é 561
# a soma de  595 + 34 é 595
# a soma de  630 + 35 é 630
# a soma de  666 + 36 é 666
# ...

# %%
n = 0
Soma = 0
while (n <= 100 ):
 Soma = n + Soma
 n = n + 1
 if n == 101 :
  print(Soma)
# Out:
# 5050
